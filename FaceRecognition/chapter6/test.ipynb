# %%
import numpy as np
import tensorflow as tf
from skimage import io

# %%
import matplotlib.pyplot as plt

# %%
img = io.imread("../datasets/lfw_mtcnnpy_160/Aaron_Eckhart/Aaron_Eckhart_0001.png")

# %%
img.shape
# Out:
# (160, 160, 3)

# %%
io.imshow(img)
plt.show()
